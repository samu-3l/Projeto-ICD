# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\jaozi\Faculdade\Programação\Introdução à Ciência de Dados\Projeto - Pokemon\Datasets\pokemon-tcg-data-master 1999-2023.csv")
frame = pd.read_csv(r"C:\Users\jaozi\Faculdade\Programação\Introdução à Ciência de Dados\Projeto - Pokemon\Datasets\Pokemon_all_tcg_wc.csv")

# %%
data
# Out:
#             id           set            series publisher generation  \
# 0      base1-1          Base              Base      WOTC      First
# 1      base1-2          Base              Base      WOTC      First
# 2      base1-3          Base              Base      WOTC      First
# 3      base1-4          Base              Base      WOTC      First
# 4      base1-5          Base              Base      WOTC      First
# ...        ...           ...               ...       ...        ...
# 17167  sv4-262  Paradox Rift  Scarlet & Violet      TPCI      Ninth
# 17168  sv4-263  Paradox Rift  Scarlet & Violet      TPCI      Ninth
# 17169  sv4-264  Paradox Rift  Scarlet & Violet      TPCI      Ninth
# 17170  sv4-265  Paradox Rift  Scarlet & Violet      TPCI      Ninth
# 17171  sv4-266  Paradox Rift  Scarlet & Violet      TPCI      Ninth
#
#       release_date           artist             name set_num      types  ...  \
# ...

# %%
frame
# Out:
#     Number  Generation                       Name  Number of cards  \
# 0        1           1                 Base Set 1              102
# 1        2           1                     Jungle               64
# 2        3           1                     Fossil               62
# 3        4           1                 Base Set 2              130
# 4        5           1                Team Rocket               83
# ..     ...         ...                        ...              ...
# 104     95           9  Scarlet & Violet Base Set              258
# 105     96           9             Paldea Evolved              279
# 106     97           9            Obsidian Flames              230
# 107     98           9               Paradox Rift              266
# 108     99           9            Temporal Forces              218
#
#           Release date  World Championship World Championship Deck  \
# 0      January 9, 1999              2004.0            Magma Spirit
# ...

# %%
cards = data.filter(items=['set', 'series', 'generation', 'name', 'set_num', 'types',
                          'supertype', 'subtypes', 'level', 'hp', 'rarity', 'nationalPokedexNumbers'])

# %%
cards
# Out:
#                 set            series generation             name set_num  \
# 0              Base              Base      First         Alakazam       1
# 1              Base              Base      First        Blastoise       2
# 2              Base              Base      First          Chansey       3
# 3              Base              Base      First        Charizard       4
# 4              Base              Base      First         Clefairy       5
# ...             ...               ...        ...              ...     ...
# 17167  Paradox Rift  Scarlet & Violet      Ninth  Roaring Moon ex     262
# 17168  Paradox Rift  Scarlet & Violet      Ninth      Beach Court     263
# 17169  Paradox Rift  Scarlet & Violet      Ninth  Counter Catcher     264
# 17170  Paradox Rift  Scarlet & Violet      Ninth   Luxurious Cape     265
# 17171  Paradox Rift  Scarlet & Violet      Ninth  Reversal Energy     266
#
#            types supertype                subtypes level     hp      rarity  \
# ...

# %%
sns.barplot(data=frame, x='Generation', y='Number of cards')
# Out:
# <Axes: xlabel='Generation', ylabel='Number of cards'>

# %%
geracoes = frame
